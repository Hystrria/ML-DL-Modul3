# 50%     85.000000   85.000000   83.000000   84.000000  ...    75.000000
# 75%     88.000000   89.000000   87.000000   88.000000  ...    75.000000
# max     99.000000   99.000000   98.000000   99.000000  ...    79.000000
#
#        1-1-kkm_ing  1-2-kkm_ing  2-1-kkm_ing  2-2-kkm_ing  1-1-kkm_mtk  \
# count   778.000000   778.000000   778.000000   778.000000   778.000000
# mean     72.231362    72.223650    73.065553    73.065553    72.172237
# std       2.881252     2.877393     3.309760     3.307037     2.904512
# min      67.000000    67.000000    67.000000    67.000000    67.000000
# 25%      70.000000    70.000000    70.000000    70.000000    70.000000
# 50%      73.000000    73.000000    73.500000    73.500000    73.000000
# 75%      75.000000    75.000000    75.000000    75.000000    75.000000
# max      78.000000    78.000000    79.000000    79.000000    78.000000
#
#        1-2-kkm_mtk  2-1-kkm_mtk  2-2-kkm_mtk         IPK
# count   778.000000   778.000000   778.000000  762.000000
# mean     72.168380    72.998715    73.017995    3.185987
# std       2.902301     3.346371     3.349206    0.801073
# min      67.000000    67.000000    67.000000    0.000000
# 25%      70.000000    70.000000    70.000000    3.056564
# 50%      73.000000    73.000000    73.000000    3.382159
# 75%      75.000000    75.000000    75.000000    3.646133
# max      78.000000    79.000000    79.000000    4.000000
#
# [8 rows x 25 columns]

# %%
print(df_ipk2['IPK'].value_counts())
# Out:
# IPK
# 0.000000    26
# 4.000000     5
# 3.979069     4
# 3.706976     4
# 3.300000     4
#             ..
# 2.131707     1
# 3.402272     1
# 3.865909     1
# 2.285714     1
# 3.569047     1
# Name: count, Length: 609, dtype: int64

# %%
print("data null \n", df_ipk2.isnull().sum())
print("data kosong \n", df_ipk2.empty)
print("data nan \n", df_ipk2.isna().sum())
# Out:
# data null
#  1-1-mtk         0
# 1-2-mtk         0
# 2-1-mtk         0
# 2-2-mtk         0
# 1-1-ing         0
# 1-2-ing         0
# 2-1-ing         0
# 2-2-ing         0
# 1-1-bhs         0
# 1-2-bhs         0
# 2-1-bhs         0
# 2-2-bhs         0
# 1-1-kkm_bhs     0
# 1-2-kkm_bhs     0
# 2-1-kkm_bhs     0
# 2-2-kkm_bhs     0
# 1-1-kkm_ing     0
# 1-2-kkm_ing     0
# 2-1-kkm_ing     0
# 2-2-kkm_ing     0
# 1-1-kkm_mtk     0
# 1-2-kkm_mtk     0
# 2-1-kkm_mtk     0
# 2-2-kkm_mtk     0
# IPK            16
# dtype: int64
# data kosong
#  False
# data nan
#  1-1-mtk         0
# 1-2-mtk         0
# 2-1-mtk         0
# 2-2-mtk         0
# 1-1-ing         0
# 1-2-ing         0
# 2-1-ing         0
# 2-2-ing         0
# 1-1-bhs         0
# 1-2-bhs         0
# 2-1-bhs         0
# 2-2-bhs         0
# 1-1-kkm_bhs     0
# 1-2-kkm_bhs     0
# 2-1-kkm_bhs     0
# 2-2-kkm_bhs     0
# 1-1-kkm_ing     0
# 1-2-kkm_ing     0
# 2-1-kkm_ing     0
# 2-2-kkm_ing     0
# 1-1-kkm_mtk     0
# 1-2-kkm_mtk     0
# 2-1-kkm_mtk     0
# 2-2-kkm_mtk     0
# IPK            16
# dtype: int64

# %%
import matplotlib.pyplot as plt

df_ipk2.IPK.plot(kind='box')
plt.gca().invert_yaxis()
plt.show()

# %%
from pandas.api.types import is_numeric_dtype
def remove_outliner(df_in):
    for col_name in list(df_in.columns):
        if is_numeric_dtype(df_in[col_name]):
            q1 = df_in[col_name].quantile(0.25)
            q3 = df_in[col_name].quantile(0.75)

            iqr = q3-q1
            batas_atas = q3 + (1.5 * iqr)
            batas_bawah = q1 - (1.5 * iqr)

            df_out = df_in.loc[(df_in[col_name] >= batas_bawah) & (df_in[col_name] <= batas_atas)]
    return df_out
    
df_ipk_clean = remove_outliner(df_ipk2)
print("Jumlah baris DataFrame sebelum dibuang outliner" ,df_ipk2.shape[0])
print("Jumlah baris DataFrame sesudah dibuang outliner" ,df_ipk_clean.shape[0])
df_ipk_clean.IPK.plot(kind='box', vert=True)

plt.gca().invert_yaxis()
plt.show()
# Out:
# Jumlah baris DataFrame sebelum dibuang outliner 778
# Jumlah baris DataFrame sesudah dibuang outliner 705

# %%
print("data null\n",df_ipk_clean.isnull().sum())
print("data kosong \n", df_ipk_clean.empty)
print("data nan \n", df_ipk_clean.isna().sum())
# Out:
# data null
#  1-1-mtk        0
# 1-2-mtk        0
# 2-1-mtk        0
# 2-2-mtk        0
# 1-1-ing        0
# 1-2-ing        0
# 2-1-ing        0
# 2-2-ing        0
# 1-1-bhs        0
# 1-2-bhs        0
# 2-1-bhs        0
# 2-2-bhs        0
# 1-1-kkm_bhs    0
# 1-2-kkm_bhs    0
# 2-1-kkm_bhs    0
# 2-2-kkm_bhs    0
# 1-1-kkm_ing    0
# 1-2-kkm_ing    0
# 2-1-kkm_ing    0
# 2-2-kkm_ing    0
# 1-1-kkm_mtk    0
# 1-2-kkm_mtk    0
# 2-1-kkm_mtk    0
# 2-2-kkm_mtk    0
# IPK            0
# dtype: int64
# data kosong
#  False
# data nan
#  1-1-mtk        0
# 1-2-mtk        0
# 2-1-mtk        0
# 2-2-mtk        0
# 1-1-ing        0
# 1-2-ing        0
# 2-1-ing        0
# 2-2-ing        0
# 1-1-bhs        0
# 1-2-bhs        0
# 2-1-bhs        0
# 2-2-bhs        0
# 1-1-kkm_bhs    0
# 1-2-kkm_bhs    0
# 2-1-kkm_bhs    0
# 2-2-kkm_bhs    0
# 1-1-kkm_ing    0
# 1-2-kkm_ing    0
# 2-1-kkm_ing    0
# 2-2-kkm_ing    0
# 1-1-kkm_mtk    0
# 1-2-kkm_mtk    0
# 2-1-kkm_mtk    0
# 2-2-kkm_mtk    0
# IPK            0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_regress = df_ipk_clean.drop('IPK', axis=1)
y_regress = df_ipk_clean.IPK

X_train_ipk, X_test_ipk, y_train_ipk, y_test_ipk = train_test_split(X_regress, y_regress, \
                                                                    test_size=0.25,
                                                                    random_state=37)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error

pipe_Ridge = Pipeline(steps=[
            ('scale',StandardScaler()),
            ('feature_selection', SelectKBest(score_func=f_regression)),
            ('reg',Ridge())
            ])

param_grid_Ridge = {
    'reg__alpha' : [0.01,0.1,1,10,100],
    'feature_selection__k' : np.arange(1,20)
}

GSCV_RR = GridSearchCV(pipe_Ridge, param_grid_Ridge, cv=5,
                        scoring='neg_mean_squared_error', error_score='raise')

GSCV_RR.fit(X_train_ipk, y_train_ipk)

print("Best model:{}".format(GSCV_RR.best_estimator_))
print("RIdge best parameters:{}".format(GSCV_RR.best_params_))
print("koefisien/bobot:{}".format(GSCV_RR.best_estimator_.named_steps['reg'].coef_))
print("Intercept/boas:{}".format(GSCV_RR.best_estimator_.named_steps['reg'].intercept_))

Ridge_predict = GSCV_RR.predict(X_test_ipk)

mse_Ridge = mean_squared_error(y_test_ipk,Ridge_predict)
mae_Ridge = mean_absolute_error(y_test_ipk,Ridge_predict)

print("Ridge Mean Squared Error (MSE): {}".format(mse_Ridge))
print("Ridge Mean Absoulte Error (MAE): {}".format(mae_Ridge))
print("Ridge Root Mean Squared Error: {}".format(np.sqrt(mse_Ridge)))
# Out:
# Best model:Pipeline(steps=[('scale', StandardScaler()),
#                 ('feature_selection',
#                  SelectKBest(k=19,
#                              score_func=<function f_regression at 0x000001B5060E2FC0>)),
#                 ('reg', Ridge(alpha=100))])
# RIdge best parameters:{'feature_selection__k': 19, 'reg__alpha': 100}
# koefisien/bobot:[ 0.01124711  0.01472615  0.0282349   0.00568083  0.0172485   0.04844563
#   0.02210458  0.02653776  0.02160065 -0.00586573  0.0096058   0.02663717
#  -0.01028166 -0.01468152 -0.01154765 -0.00618884 -0.02706799  0.01665055
#   0.01503475]
# Intercept/boas:3.377228837121212
# Ridge Mean Squared Error (MSE): 0.10316539022994037
# Ridge Mean Absoulte Error (MAE): 0.2632363909624947
# Ridge Root Mean Squared Error: 0.3211936958128854

# %%
df_results = pd.DataFrame(y_test_ipk, columns=['IPK'])
df_results = pd.DataFrame(y_test_ipk)
df_results['Ridge Prediction'] = Ridge_predict

df_results['Selisih_IPK_RR'] = df_results['Ridge Prediction'] - df_results['IPK']

df_results.head()
# Out:
#           IPK  Ridge Prediction  Selisih_IPK_RR
# 413  2.812500          3.412898        0.600398
# 566  3.780487          3.314920       -0.465567
# 504  2.852500          3.247662        0.395162
# 273  3.141666          3.339015        0.197349
# 0    4.000000          3.576106       -0.423894

# %%
df_results.describe()
# Out:
#               IPK  Ridge Prediction  Selisih_IPK_RR
# count  177.000000        177.000000      177.000000
# mean     3.393854          3.370746       -0.023108
# std      0.360216          0.157460        0.321270
# min      2.175000          3.036639       -0.612602
# 25%      3.158139          3.266686       -0.265986
# 50%      3.431111          3.369032       -0.078979
# 75%      3.688372          3.478845        0.171034
# max      4.000000          3.847264        0.947733

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error

pipe_Lasso = Pipeline(steps=[
            ('scale',StandardScaler()),
            ('feature_selection', SelectKBest(score_func=f_regression)),
            ('reg',Lasso(max_iter=1000))
            ])

param_grid_Lasso = {
    'reg__alpha' : [0.01,0.1,1,10,100],
    'feature_selection__k' : np.arange(1,20)
}

GSCV_Lasso = GridSearchCV(pipe_Lasso, param_grid_Lasso, cv=5,scoring='neg_mean_squared_error')

GSCV_Lasso.fit(X_train_ipk, y_train_ipk)

print("Best model:{}".format(GSCV_Lasso.best_estimator_))
print("Lasso best parameters:{}".format(GSCV_Lasso.best_params_))
print("koefisien/bobot:{}".format(GSCV_Lasso.best_estimator_.named_steps['reg'].coef_))
print("Intercept/boas:{}".format(GSCV_Lasso.best_estimator_.named_steps['reg'].intercept_))

Lasso_predict = GSCV_Lasso.predict(X_test_ipk)

mse_Lasso = mean_squared_error(y_test_ipk,Lasso_predict)
mae_Lasso = mean_absolute_error(y_test_ipk,Lasso_predict)

print("Lasso Mean Squared Error (MSE): {}".format(mse_Lasso))
print("Lasso Mean Absoulte Error (MAE): {}".format(mae_Lasso))
print("Lasso Root Mean Squared Error: {}".format(np.sqrt(mse_Lasso)))
# Out:
# Best model:Pipeline(steps=[('scale', StandardScaler()),
#                 ('feature_selection',
#                  SelectKBest(k=19,
#                              score_func=<function f_regression at 0x000001B5060E2FC0>)),
#                 ('reg', Lasso(alpha=0.01))])
# Lasso best parameters:{'feature_selection__k': 19, 'reg__alpha': 0.01}
# koefisien/bobot:[ 0.00588592  0.01388188  0.02967965  0.          0.01053204  0.05774493
#   0.01979139  0.02723746  0.0148903   0.          0.00018584  0.02817391
#  -0.         -0.0027949  -0.         -0.         -0.02447558 -0.
#  -0.        ]
# Intercept/boas:3.377228837121212
# Lasso Mean Squared Error (MSE): 0.10279905334700008
# Lasso Mean Absoulte Error (MAE): 0.26332971247715964
# Lasso Root Mean Squared Error: 0.32062291456943637

# %%
df_results['Lasso Prediction'] = Lasso_predict
df_results = pd.DataFrame(y_test_ipk)
df_results['Lasso Prediction'] = Lasso_predict

df_results['Selisih_IPK_LR'] = df_results['Lasso Prediction'] - df_results['IPK']
df_results.head()
# Out:
#           IPK  Lasso Prediction  Selisih_IPK_LR
# 413  2.812500          3.414495        0.601995
# 566  3.780487          3.338010       -0.442477
# 504  2.852500          3.278685        0.426185
# 273  3.141666          3.327954        0.186288
# 0    4.000000          3.591203       -0.408797

# %%
df_results.describe()
# Out:
#               IPK  Lasso Prediction  Selisih_IPK_LR
# count  177.000000        177.000000      177.000000
# mean     3.393854          3.369759       -0.024095
# std      0.360216          0.147813        0.320623
# min      2.175000          3.045307       -0.606288
# 25%      3.158139          3.274668       -0.262885
# 50%      3.431111          3.368451       -0.069790
# 75%      3.688372          3.469824        0.174107
# max      4.000000          3.805200        0.963254

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error

pipe_SVR = Pipeline(steps=[
            ('scale',StandardScaler()),
            ('feature_selection', SelectKBest(score_func=f_regression)),
            ('reg',SVR(kernel='linear'))
            ])

param_grid_SVR = {
    'reg__C' : [0.01, 0.1, 1, 10, 100],
    'reg__epsilon' : [0.1, 0.2, 0.5, 1],
    'feature_selection__k' : np.arange(1,20)
}

GSCV_SVR = GridSearchCV(pipe_SVR, param_grid_SVR, cv=5,scoring='neg_mean_squared_error')

GSCV_SVR.fit(X_train_ipk, y_train_ipk)

print("Best model:{}".format(GSCV_SVR.best_estimator_))
print("SVR best parameters:{}".format(GSCV_SVR.best_params_))
print("koefisien/bobot:{}".format(GSCV_SVR.best_estimator_.named_steps['reg'].coef_))
print("Intercept/boas:{}".format(GSCV_SVR.best_estimator_.named_steps['reg'].intercept_))

SVR_predict = GSCV_SVR.predict(X_test_ipk)

mse_SVR = mean_squared_error(y_test_ipk,SVR_predict)
mae_SVR = mean_absolute_error(y_test_ipk,SVR_predict)

print("SVR Mean Squared Error (MSE): {}".format(mse_SVR))
print("SVR Mean Absoulte Error (MAE): {}".format(mae_SVR))
print("SVR Root Mean Squared Error: {}".format(np.sqrt(mse_SVR)))
# Out:
# Best model:Pipeline(steps=[('scale', StandardScaler()),
#                 ('feature_selection',
#                  SelectKBest(k=18,
#                              score_func=<function f_regression at 0x000001B5060E2FC0>)),
#                 ('reg', SVR(C=0.01, epsilon=0.2, kernel='linear'))])
# SVR best parameters:{'feature_selection__k': 18, 'reg__C': 0.01, 'reg__epsilon': 0.2}
# koefisien/bobot:[[ 0.00451998 -0.00173947  0.02278016  0.01740184  0.01249444  0.06665387
#    0.02553557  0.02865418  0.03254477 -0.01881595  0.01812346  0.03490479
#   -0.01032231 -0.01930019 -0.02824073 -0.01331689  0.01404203  0.01406062]]
# Intercept/boas:[3.39676541]
# SVR Mean Squared Error (MSE): 0.10353910197859752
# SVR Mean Absoulte Error (MAE): 0.2614942100409816
# SVR Root Mean Squared Error: 0.32177492440927946

# %%
df_results['SVR Prediction'] = SVR_predict
df_results = pd.DataFrame(y_test_ipk)
df_results['SVR Prediction'] = SVR_predict

df_results['Selisih_IPK_SVR'] = df_results['SVR Prediction'] - df_results['IPK']
df_results.head()
# Out:
#           IPK  SVR Prediction  Selisih_IPK_SVR
# 413  2.812500        3.400742         0.588242
# 566  3.780487        3.299983        -0.480504
# 504  2.852500        3.212523         0.360023
# 273  3.141666        3.394653         0.252987
# 0    4.000000        3.596128        -0.403872

# %%
df_results.describe()
# Out:
#               IPK  SVR Prediction  Selisih_IPK_SVR
# count  177.000000      177.000000       177.000000
# mean     3.393854        3.386105        -0.007748
# std      0.360216        0.172436         0.322594
# min      2.175000        3.017873        -0.624065
# 25%      3.158139        3.255507        -0.251047
# 50%      3.431111        3.390441        -0.047014
# 75%      3.688372        3.505698         0.203330
# max      4.000000        3.904768         0.931196

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error

pipe_GBR = Pipeline(steps=[
            ('scale',StandardScaler()),
            ('feature_selection', SelectKBest(score_func=f_regression)),
            
            ('reg', GradientBoostingRegressor())
            ])

param_grid_GBR = {
    'reg__n_estimators' : [100, 200, 300],
    'reg__learning_rate' : [0.01, 0.1, 0.2],
    'reg__max_depth' : [3, 4, 5],
    'feature_selection__k' : np.arange(1,20)
}

GSCV_GBR = GridSearchCV(pipe_GBR, param_grid_GBR, cv=5, scoring='neg_mean_squared_error')

GSCV_GBR.fit(X_train_ipk, y_train_ipk)

print("Best model:{}".format(GSCV_GBR.best_estimator_))
print("GBR best parameters:{}".format(GSCV_GBR.best_params_))

print("Feature Importances:{}".format(GSCV_GBR.best_estimator_.named_steps['reg'].feature_importances_))

GBR_predict = GSCV_GBR.predict(X_test_ipk)

mse_GBR = mean_squared_error(y_test_ipk,GBR_predict)
mae_GBR = mean_absolute_error(y_test_ipk,GBR_predict)

print("GBR Mean Squared Error (MSE): {}".format(mse_GBR))
print("SVR Mean Absoulte Error (MAE): {}".format(mae_GBR))
print("GBR Root Mean Squared Error: {}".format(np.sqrt(mse_GBR)))
# Out:
# Best model:Pipeline(steps=[('scale', StandardScaler()),
#                 ('feature_selection',
#                  SelectKBest(k=19,
#                              score_func=<function f_regression at 0x000001B5060E2FC0>)),
#                 ('reg',
#                  GradientBoostingRegressor(learning_rate=0.01,
#                                            n_estimators=200))])
# GBR best parameters:{'feature_selection__k': 19, 'reg__learning_rate': 0.01, 'reg__max_depth': 3, 'reg__n_estimators': 200}
# Feature Importances:[0.04244088 0.04173169 0.1194391  0.00490473 0.0390086  0.28585439
#  0.12715474 0.10116574 0.05074101 0.03448955 0.04105907 0.06081087
#  0.01020525 0.01538797 0.00270879 0.00159086 0.01691242 0.00139382
#  0.00300051]
# GBR Mean Squared Error (MSE): 0.10409419875103545
# SVR Mean Absoulte Error (MAE): 0.26788497353736046
# GBR Root Mean Squared Error: 0.32263632583922636

# %%
df_results['GBR Prediction'] = GBR_predict
df_results = pd.DataFrame(y_test_ipk)
df_results['GBR Prediction'] = GBR_predict

df_results['Selisih_IPK_GBR'] = df_results['GBR Prediction'] - df_results['IPK']
df_results.head()
# Out:
#           IPK  GBR Prediction  Selisih_IPK_GBR
# 413  2.812500        3.422199         0.609699
# 566  3.780487        3.240337        -0.540150
# 504  2.852500        3.404548         0.552048
# 273  3.141666        3.253112         0.111446
# 0    4.000000        3.593849        -0.406151

# %%
df_results.describe()
# Out:
#               IPK  GBR Prediction  Selisih_IPK_GBR
# count  177.000000      177.000000       177.000000
# mean     3.393854        3.359676        -0.034178
# std      0.360216        0.145779         0.321731
# min      2.175000        3.014131        -0.647609
# 25%      3.158139        3.253112        -0.289606
# 50%      3.431111        3.392522        -0.067656
# 75%      3.688372        3.447682         0.173105
# max      4.000000        3.636887         0.881785

# %%
df_results = pd.DataFrame({'IPK': y_test_ipk})

df_results['Ridge Prediction'] = Ridge_predict
df_results['Selisih_IPK_RR'] = df_results['IPK'] - df_results['Ridge Prediction']

df_results['Lasso Prediction'] = Lasso_predict
df_results['Selisih_IPK_LR'] = df_results['IPK'] - df_results['Lasso Prediction']

df_results['SVR Prediction'] = SVR_predict
df_results['Selisih_IPK_SVR'] = df_results['IPK'] - df_results['SVR Prediction']

df_results['GBR Prediction'] = GBR_predict
df_results['Selisih_IPK_GBR'] = df_results['IPK'] - df_results['GBR Prediction']

df_results.head()
# Out:
#           IPK  Ridge Prediction  Selisih_IPK_RR  Lasso Prediction  \
# 413  2.812500          3.412898       -0.600398          3.414495
# 566  3.780487          3.314920        0.465567          3.338010
# 504  2.852500          3.247662       -0.395162          3.278685
# 273  3.141666          3.339015       -0.197349          3.327954
# 0    4.000000          3.576106        0.423894          3.591203
#
#      Selisih_IPK_LR  SVR Prediction  Selisih_IPK_SVR  GBR Prediction  \
# 413       -0.601995        3.400742        -0.588242        3.422199
# 566        0.442477        3.299983         0.480504        3.240337
# 504       -0.426185        3.212523        -0.360023        3.404548
# 273       -0.186288        3.394653        -0.252987        3.253112
# 0          0.408797        3.596128         0.403872        3.593849
#
#      Selisih_IPK_GBR
# 413        -0.609699
# 566         0.540150
# 504        -0.552048
# 273        -0.111446
# 0           0.406151

# %%
df_results.describe()
# Out:
#               IPK  Ridge Prediction  Selisih_IPK_RR  Lasso Prediction  \
# count  177.000000        177.000000      177.000000        177.000000
# mean     3.393854          3.370746        0.023108          3.369759
# std      0.360216          0.157460        0.321270          0.147813
# min      2.175000          3.036639       -0.947733          3.045307
# 25%      3.158139          3.266686       -0.171034          3.274668
# 50%      3.431111          3.369032        0.078979          3.368451
# 75%      3.688372          3.478845        0.265986          3.469824
# max      4.000000          3.847264        0.612602          3.805200
#
#        Selisih_IPK_LR  SVR Prediction  Selisih_IPK_SVR  GBR Prediction  \
# count      177.000000      177.000000       177.000000      177.000000
# mean         0.024095        3.386105         0.007748        3.359676
# std          0.320623        0.172436         0.322594        0.145779
# min         -0.963254        3.017873        -0.931196        3.014131
# 25%         -0.174107        3.255507        -0.203330        3.253112
# 50%          0.069790        3.390441         0.047014        3.392522
# 75%          0.262885        3.505698         0.251047        3.447682
# max          0.606288        3.904768         0.624065        3.636887
#
#        Selisih_IPK_GBR
# count       177.000000
# mean          0.034178
# std           0.321731
# min          -0.881785
# 25%          -0.173105
# 50%           0.067656
# 75%           0.289606
# max           0.647609

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
data_len = range(len(y_test_ipk))
plt.scatter(data_len, df_results.IPK, label="actual", color="blue")
plt.plot(data_len, df_results['Ridge Prediction'], label="Ridge Prediction", color="green", linewidth=4, linestyle="dashed")
plt.plot(data_len, df_results['Lasso Prediction'], label="Lasso Prediction", color="black", linewidth=3, linestyle="--")
plt.plot(data_len, df_results['SVR Prediction'], label="SVR Prediction", color="yellow", linewidth=2, linestyle="-.")
plt.plot(data_len, df_results['GBR Prediction'], label="GBR Prediction", color="red", linewidth=1, linestyle=":")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae_ridge = mean_absolute_error(df_results['IPK'], df_results['Ridge Prediction'])
rmse_ridge = np.sqrt(mean_squared_error(df_results['IPK'], df_results['Ridge Prediction']))
ridge_feature_count = GSCV_RR.best_params_['feature_selection__k']

mae_lasso = mean_absolute_error(df_results['IPK'], df_results['Lasso Prediction'])
rmse_lasso = np.sqrt(mean_squared_error(df_results['IPK'], df_results['Lasso Prediction']))
lasso_feature_count = GSCV_Lasso.best_params_['feature_selection__k']

mae_svr = mean_absolute_error(df_results['IPK'], df_results['SVR Prediction'])
rmse_svr = np.sqrt(mean_squared_error(df_results['IPK'], df_results['SVR Prediction']))
svr_feature_count = GSCV_SVR.best_params_['feature_selection__k']

mae_gbr = mean_absolute_error(df_results['IPK'], df_results['GBR Prediction'])
rmse_gbr = np.sqrt(mean_squared_error(df_results['IPK'], df_results['GBR Prediction']))
gbr_feature_count = GSCV_GBR.best_params_['feature_selection__k']

print(f"Ridge MAE: {mae_ridge}, Ridge RMSE: {rmse_ridge}, Ridge Feature Count: {ridge_feature_count}")
print(f"Lasso MAE: {mae_lasso}, Lasso RMSE: {rmse_lasso}, Lasso Feature Count: {lasso_feature_count}")
print(f"SVR MAE: {mae_svr}, SVR RMSE: {rmse_svr}, SVR Feature Count: {svr_feature_count}")
print(f"GBR MAE: {mae_gbr}, GBR RMSE: {rmse_gbr}, GBR Feature Count: {gbr_feature_count}")
# Out:
# Ridge MAE: 0.2632363909624947, Ridge RMSE: 0.3211936958128854, Ridge Feature Count: 19
# Lasso MAE: 0.26332971247715964, Lasso RMSE: 0.32062291456943637, Lasso Feature Count: 19
# SVR MAE: 0.2614942100409816, SVR RMSE: 0.32177492440927946, SVR Feature Count: 18
# GBR MAE: 0.26788497353736046, GBR RMSE: 0.32263632583922636, GBR Feature Count: 19

# %%
import pickle

best_model = GSCV_SVR.best_estimator_

with open('SVR_IPK_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

print("Model terbaik berhasil disimpan ke 'SVR_IPK_model.pkl'")
# Out:
# Model terbaik berhasil disimpan ke 'SVR_IPK_model.pkl'
